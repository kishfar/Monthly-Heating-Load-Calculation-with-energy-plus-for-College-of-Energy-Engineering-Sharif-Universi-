# %%
import os
import opyplus as op
import warnings
warnings.filterwarnings("ignore")

eplus_dir_path = op.get_eplus_base_dir_path((9, 2, 0))

# %%
# idf path
idf_path = os.path.join(
    eplus_dir_path,
    "ExampleFiles",
    "DOEE-EnergyPlus V0.1.2(NORTH).idf"
)

# epw path
epw_path = os.path.join(
    eplus_dir_path,
    "WeatherData",
    "IRN_Tehran-Mehrabad.407540_ITMY.epw"
)

base_dir_path = os.path.join(
    eplus_dir_path,
    "Result","Tehran(NORTH)"
) 
# run simulation
s = op.simulate(
    idf_path,
    epw_path,
    base_dir_path,
    simulation_name=None,
    print_function=None,
    beat_freq=None,
)
# Out:
# called Simulation.from_input on a simulation directory that is not empty (C:\\EnergyPlusV9-2-0\Result\Tehran)

# %%
print(f"status: {s.get_status()}\n")
print(f"Eplus .err file:\n{s.get_out_err().get_content()}")
# Out:
# status: finished
#
# Eplus .err file:
# Program Version,EnergyPlus, Version 9.2.0-921312fa1d, YMD=2022.01.31 13:58,
#    ** Warning ** ProcessScheduleInput: Schedule:Day:Interval="SCHEDULE DAY 1", , One or more values are not integer as required by Schedule Type Limits Name=ONOFF
#    ** Warning ** ProcessScheduleInput: Schedule:Constant="ALWAYS OFF DISCRETE", Blank Schedule Type Limits Name input -- will not be validated.
#    ** Warning ** ProcessScheduleInput: Schedule:Constant="ALWAYS ON CONTINUOUS", Blank Schedule Type Limits Name input -- will not be validated.
#    ************* Beginning Zone Sizing Calculations
#    ** Warning ** GetHTSurfaceData: Surfaces with interface to Ground found but no "Ground Temperatures" were input.
#    **   ~~~   ** Found first in surface=SURFACE 400
#    **   ~~~   ** Defaults, constant throughout the year of (18.0) will be used.
#    ** Warning ** GetSurfaceData: Construction INTERIOR CEILING of interzone surface SURFACE 405 does not have the same materials in the reverse order as the construction INTERIOR FLOOR of adjacent surface SURFACE 406
#    **   ~~~   ** or the properties of the reversed layers are not correct due to differing layer front and back side values
#    **   ~~~   ** ...but Nominal U values are similar, diff=[0.0000] ... simulation proceeds.
#    **   ~~~   ** ...if the two zones are expected to have significantly different temperatures, the proper "reverse" construction should be created.
#    **   ~~~   ** ...this problem for this pair will not be reported again.
#    ** Warning ** CalculateZoneVolume: 1 zone is not fully enclosed. For more details use:  Output:Diagnostics,DisplayExtrawarnings;
#    ** Warning ** CheckUsedConstructions: There are 4 nominally unused constructions in input.
#    **   ~~~   ** For explicit details on each unused construction, use Output:Diagnostics,DisplayExtraWarnings;
#    ************* Beginning System Sizing Calculations
#    ** Warning ** Since Zone Minimum Air Flow Input Method = CONSTANT, input for Fixed Minimum Air Flow Rate will be ignored.
#    **   ~~~   ** Occurs in AirTerminal:SingleDuct:VAV:Reheat = VAV HW RHT AMPHITHEATER
#    ** Warning ** Since Zone Minimum Air Flow Input Method = CONSTANT, input for Fixed Minimum Air Flow Rate will be ignored.
#    **   ~~~   ** Occurs in AirTerminal:SingleDuct:VAV:Reheat = VAV HW RHT CONFERANCE
#    ** Warning ** Since Zone Minimum Air Flow Input Method = CONSTANT, input for Fixed Minimum Air Flow Rate will be ignored.
#    **   ~~~   ** Occurs in AirTerminal:SingleDuct:VAV:Reheat = VAV HW RHT LAB
#    ** Warning ** Since Zone Minimum Air Flow Input Method = CONSTANT, input for Fixed Minimum Air Flow Rate will be ignored.
#    **   ~~~   ** Occurs in AirTerminal:SingleDuct:VAV:Reheat = VAV HW RHT LIBRARY
#    ** Warning ** Since Zone Minimum Air Flow Input Method = CONSTANT, input for Fixed Minimum Air Flow Rate will be ignored.
#    **   ~~~   ** Occurs in AirTerminal:SingleDuct:VAV:Reheat = VAV HW RHT NORTH1
#    ** Warning ** Since Zone Minimum Air Flow Input Method = CONSTANT, input for Fixed Minimum Air Flow Rate will be ignored.
#    **   ~~~   ** Occurs in AirTerminal:SingleDuct:VAV:Reheat = VAV HW RHT  NORTH2
#    ** Warning ** Since Zone Minimum Air Flow Input Method = CONSTANT, input for Fixed Minimum Air Flow Rate will be ignored.
#    **   ~~~   ** Occurs in AirTerminal:SingleDuct:VAV:Reheat = VAV HW RHT NORTH3
#    ** Warning ** Since Zone Minimum Air Flow Input Method = CONSTANT, input for Fixed Minimum Air Flow Rate will be ignored.
#    **   ~~~   ** Occurs in AirTerminal:SingleDuct:VAV:Reheat = VAV HW RHT NORTH-GF
#    ** Warning ** Since Zone Minimum Air Flow Input Method = CONSTANT, input for Fixed Minimum Air Flow Rate will be ignored.
#    **   ~~~   ** Occurs in AirTerminal:SingleDuct:VAV:Reheat = VAV HW RHT SOUTH-1
#    ** Warning ** Since Zone Minimum Air Flow Input Method = CONSTANT, input for Fixed Minimum Air Flow Rate will be ignored.
#    **   ~~~   ** Occurs in AirTerminal:SingleDuct:VAV:Reheat = VAV HW RHT SOUTH-2
#    ** Warning ** Since Zone Minimum Air Flow Input Method = CONSTANT, input for Fixed Minimum Air Flow Rate will be ignored.
#    **   ~~~   ** Occurs in AirTerminal:SingleDuct:VAV:Reheat = VAV HW RHT SOUTH-3
#    ** Warning ** Since Zone Minimum Air Flow Input Method = CONSTANT, input for Fixed Minimum Air Flow Rate will be ignored.
#    **   ~~~   ** Occurs in AirTerminal:SingleDuct:VAV:Reheat = VAV HW RHT SOUTH-GF
#    ** Warning ** HVACControllers: GetControllerInput: Controller:WaterCoil="CONTROLLER WATER COIL 2":
#    **   ~~~   ** ...Normal action has been specified for a cooling coil - should be Reverse.
#    **   ~~~   ** ...overriding user input action with Reverse Action.
#    ************* Beginning Plant Sizing Calculations
#    ** Warning ** SizeWaterCoil: Coil="FAN COIL WITH VAR FAN CONST FLUID FLOW - COOLING COIL", Cooling Coil has leaving humidity ratio > entering humidity ratio.
#    **   ~~~   **     Wair,in =  8.373998E-003
#    **   ~~~   **     Wair,out = 8.500000E-003
#    **   ~~~   ** ....coil leaving humidity ratio will be reset to:
#    **   ~~~   **     Wair,out = 8.373998E-003
#    ** Warning ** SizeWaterCoil: Coil="FAN COIL WITH VAR FAN CONST FLUID FLOW - COOLING COIL 3", Cooling Coil has leaving humidity ratio > entering humidity ratio.
#    **   ~~~   **     Wair,in =  8.380239E-003
#    **   ~~~   **     Wair,out = 8.500000E-003
#    **   ~~~   ** ....coil leaving humidity ratio will be reset to:
#    **   ~~~   **     Wair,out = 8.380239E-003
#    ** Warning ** SizeWaterCoil: Coil="FAN COIL WITH VAR FAN CONST FLUID FLOW - COOLING COIL 4", Cooling Coil has leaving humidity ratio > entering humidity ratio.
#    **   ~~~   **     Wair,in =  8.403095E-003
#    **   ~~~   **     Wair,out = 8.500000E-003
#    **   ~~~   ** ....coil leaving humidity ratio will be reset to:
#    **   ~~~   **     Wair,out = 8.403095E-003
#    ** Warning ** SizeWaterCoil: Coil="FAN COIL WITH VAR FAN CONST FLUID FLOW - COOLING COIL 1", Cooling Coil has leaving humidity ratio > entering humidity ratio.
#    **   ~~~   **     Wair,in =  8.257901E-003
#    **   ~~~   **     Wair,out = 8.500000E-003
#    **   ~~~   ** ....coil leaving humidity ratio will be reset to:
#    **   ~~~   **     Wair,out = 8.257901E-003
#    ** Warning ** SizeWaterCoil: Coil="FAN COIL WITH VAR FAN CONST FLUID FLOW - COOLING COIL 2", Cooling Coil has leaving humidity ratio > entering humidity ratio.
#    **   ~~~   **     Wair,in =  8.354764E-003
#    **   ~~~   **     Wair,out = 8.500000E-003
#    **   ~~~   ** ....coil leaving humidity ratio will be reset to:
#    **   ~~~   **     Wair,out = 8.354764E-003
#    ** Warning ** ZoneHVAC:FourPipeFanCoil="FAN COIL- CORRIDOE1- VAR FAN CONST FLUID FLOW" -- Exceeded max iterations while adjusting cycling fan sensible runtime to meet the zone load within the cooling convergence tolerance.
#    **   ~~~   ** Iterations=100 During Warmup, Environment=TEHRAN MEHRABAD ANN CLG .4% CONDNS DB=>MWB, at Simulation time=07/21 00:00 - 00:10
#    ** Warning ** ZoneHVAC:FourPipeFanCoil="FAN COIL- CORRIDOE2- VAR FAN CONST FLUID FLOW" -- Exceeded max iterations while adjusting cycling fan sensible runtime to meet the zone load within the cooling convergence tolerance.
#    **   ~~~   ** Iterations=100 During Warmup, Environment=TEHRAN MEHRABAD ANN CLG .4% CONDNS DB=>MWB, at Simulation time=07/21 00:00 - 00:10
#    ** Warning ** ZoneHVAC:FourPipeFanCoil="FAN COIL- CORRIDOE3- VAR FAN CONST FLUID FLOW" -- Exceeded max iterations while adjusting cycling fan sensible runtime to meet the zone load within the cooling convergence tolerance.
#    **   ~~~   ** Iterations=100 During Warmup, Environment=TEHRAN MEHRABAD ANN CLG .4% CONDNS DB=>MWB, at Simulation time=07/21 00:00 - 00:10
#    ** Warning ** ZoneHVAC:FourPipeFanCoil="FAN COIL- CORRIDOEG- VAR FAN CONST FLUID FLOW" -- Exceeded max iterations while adjusting cycling fan sensible runtime to meet the zone load within the cooling convergence tolerance.
#    **   ~~~   ** Iterations=100 During Warmup, Environment=TEHRAN MEHRABAD ANN CLG .4% CONDNS DB=>MWB, at Simulation time=07/21 00:00 - 00:10
#    ** Warning ** SizeWaterCoil: Coil="AMPHITHEATER COIL COOLING WATER", Cooling Coil has leaving humidity ratio > entering humidity ratio.
#    **   ~~~   **     Wair,in =  7.911038E-003 [KGWATER/KGDRYAIR]
#    **   ~~~   **     Wair,out = 8.500000E-003 [KGWATER/KGDRYAIR]
#    **   ~~~   ** ....coil leaving humidity ratio will be reset to:
#    **   ~~~   **     Wair,out = 7.911038E-003 [KGWATER/KGDRYAIR]
#    ** Warning ** The design coil load is zero for Coil:Heating:Water AMPHITHEATER COIL HEATING WATER
#    **   ~~~   ** The autosize value for maximum water flow rate is zero
#    **   ~~~   ** To change this, input a value for UA, change the heating design day, or raise the
#    **   ~~~   **   system heating design supply air temperature. Also check to make sure the Preheat
#    **   ~~~   **   Design Temperature is not the same as the Central Heating Design Supply Air Temperature.
#    ** Warning ** SizeWaterCoil: Coil="LAB COIL COOLING WATER", Cooling Coil has leaving humidity ratio > entering humidity ratio.
#    **   ~~~   **     Wair,in =  7.911042E-003 [KGWATER/KGDRYAIR]
#    **   ~~~   **     Wair,out = 8.500000E-003 [KGWATER/KGDRYAIR]
#    **   ~~~   ** ....coil leaving humidity ratio will be reset to:
#    **   ~~~   **     Wair,out = 7.911042E-003 [KGWATER/KGDRYAIR]
#    ** Warning ** The design coil load is zero for Coil:Heating:Water LAB COIL HEATING WATER
#    **   ~~~   ** The autosize value for maximum water flow rate is zero
#    **   ~~~   ** To change this, input a value for UA, change the heating design day, or raise the
#    **   ~~~   **   system heating design supply air temperature. Also check to make sure the Preheat
#    **   ~~~   **   Design Temperature is not the same as the Central Heating Design Supply Air Temperature.
#    ** Warning ** SizeWaterCoil: Coil="LIBRARY COIL COOLING WATER", Cooling Coil has leaving humidity ratio > entering humidity ratio.
#    **   ~~~   **     Wair,in =  7.911042E-003 [KGWATER/KGDRYAIR]
#    **   ~~~   **     Wair,out = 8.500000E-003 [KGWATER/KGDRYAIR]
#    **   ~~~   ** ....coil leaving humidity ratio will be reset to:
#    **   ~~~   **     Wair,out = 7.911042E-003 [KGWATER/KGDRYAIR]
#    ** Warning ** The design coil load is zero for Coil:Heating:Water LIBRARY COIL HEATING WATER
#    **   ~~~   ** The autosize value for maximum water flow rate is zero
#    **   ~~~   ** To change this, input a value for UA, change the heating design day, or raise the
#    **   ~~~   **   system heating design supply air temperature. Also check to make sure the Preheat
#    **   ~~~   **   Design Temperature is not the same as the Central Heating Design Supply Air Temperature.
#    ** Warning ** SizeWaterCoil: Coil="NORTH-GF COIL COOLING WATER", Cooling Coil has leaving humidity ratio > entering humidity ratio.
#    **   ~~~   **     Wair,in =  7.911042E-003 [KGWATER/KGDRYAIR]
#    **   ~~~   **     Wair,out = 8.500000E-003 [KGWATER/KGDRYAIR]
#    **   ~~~   ** ....coil leaving humidity ratio will be reset to:
#    **   ~~~   **     Wair,out = 7.911042E-003 [KGWATER/KGDRYAIR]
#    ** Warning ** The design coil load is zero for Coil:Heating:Water NORTH-GF COIL HEATING WATER
#    **   ~~~   ** The autosize value for maximum water flow rate is zero
#    **   ~~~   ** To change this, input a value for UA, change the heating design day, or raise the
#    **   ~~~   **   system heating design supply air temperature. Also check to make sure the Preheat
#    **   ~~~   **   Design Temperature is not the same as the Central Heating Design Supply Air Temperature.
#    ** Warning ** SizeWaterCoil: Coil="NORTH1-2 COIL COOLING WATER", Cooling Coil has leaving humidity ratio > entering humidity ratio.
#    **   ~~~   **     Wair,in =  7.911042E-003 [KGWATER/KGDRYAIR]
#    **   ~~~   **     Wair,out = 8.500000E-003 [KGWATER/KGDRYAIR]
#    **   ~~~   ** ....coil leaving humidity ratio will be reset to:
#    **   ~~~   **     Wair,out = 7.911042E-003 [KGWATER/KGDRYAIR]
#    ** Warning ** The design coil load is zero for Coil:Heating:Water NORTH1-2 COIL HEATING WATER
#    **   ~~~   ** The autosize value for maximum water flow rate is zero
#    **   ~~~   ** To change this, input a value for UA, change the heating design day, or raise the
#    **   ~~~   **   system heating design supply air temperature. Also check to make sure the Preheat
#    **   ~~~   **   Design Temperature is not the same as the Central Heating Design Supply Air Temperature.
#    ** Warning ** SizeWaterCoil: Coil="NORTH3 COIL COOLING WATER", Cooling Coil has leaving humidity ratio > entering humidity ratio.
#    **   ~~~   **     Wair,in =  7.911042E-003 [KGWATER/KGDRYAIR]
#    **   ~~~   **     Wair,out = 8.500000E-003 [KGWATER/KGDRYAIR]
#    **   ~~~   ** ....coil leaving humidity ratio will be reset to:
#    **   ~~~   **     Wair,out = 7.911042E-003 [KGWATER/KGDRYAIR]
#    ** Warning ** The design coil load is zero for Coil:Heating:Water NORTH3 COIL HEATING WATER
#    **   ~~~   ** The autosize value for maximum water flow rate is zero
#    **   ~~~   ** To change this, input a value for UA, change the heating design day, or raise the
#    **   ~~~   **   system heating design supply air temperature. Also check to make sure the Preheat
#    **   ~~~   **   Design Temperature is not the same as the Central Heating Design Supply Air Temperature.
#    ** Warning ** SizeWaterCoil: Coil="SOUTH-GF COIL COOLING WATER", Cooling Coil has leaving humidity ratio > entering humidity ratio.
#    **   ~~~   **     Wair,in =  7.911036E-003 [KGWATER/KGDRYAIR]
#    **   ~~~   **     Wair,out = 8.500000E-003 [KGWATER/KGDRYAIR]
#    **   ~~~   ** ....coil leaving humidity ratio will be reset to:
#    **   ~~~   **     Wair,out = 7.911036E-003 [KGWATER/KGDRYAIR]
#    ** Warning ** The design coil load is zero for Coil:Heating:Water SOUTH-GF COIL HEATING WATER
#    **   ~~~   ** The autosize value for maximum water flow rate is zero
#    **   ~~~   ** To change this, input a value for UA, change the heating design day, or raise the
#    **   ~~~   **   system heating design supply air temperature. Also check to make sure the Preheat
#    **   ~~~   **   Design Temperature is not the same as the Central Heating Design Supply Air Temperature.
#    ** Warning ** SizeWaterCoil: Coil="SOUTH1-2 COIL COOLING WATER", Cooling Coil has leaving humidity ratio > entering humidity ratio.
#    **   ~~~   **     Wair,in =  7.911039E-003 [KGWATER/KGDRYAIR]
#    **   ~~~   **     Wair,out = 8.500000E-003 [KGWATER/KGDRYAIR]
#    **   ~~~   ** ....coil leaving humidity ratio will be reset to:
#    **   ~~~   **     Wair,out = 7.911039E-003 [KGWATER/KGDRYAIR]
#    ** Warning ** The design coil load is zero for Coil:Heating:Water SOUTH1-2 COIL HEATING WATER
#    **   ~~~   ** The autosize value for maximum water flow rate is zero
#    **   ~~~   ** To change this, input a value for UA, change the heating design day, or raise the
#    **   ~~~   **   system heating design supply air temperature. Also check to make sure the Preheat
#    **   ~~~   **   Design Temperature is not the same as the Central Heating Design Supply Air Temperature.
#    ** Warning ** SizeWaterCoil: Coil="SOUTH3 COIL COOLING WATER", Cooling Coil has leaving humidity ratio > entering humidity ratio.
#    **   ~~~   **     Wair,in =  7.911042E-003 [KGWATER/KGDRYAIR]
#    **   ~~~   **     Wair,out = 8.500000E-003 [KGWATER/KGDRYAIR]
#    **   ~~~   ** ....coil leaving humidity ratio will be reset to:
#    **   ~~~   **     Wair,out = 7.911042E-003 [KGWATER/KGDRYAIR]
#    ** Warning ** The design coil load is zero for Coil:Heating:Water SOUTH3 COIL HEATING WATER
#    **   ~~~   ** The autosize value for maximum water flow rate is zero
#    **   ~~~   ** To change this, input a value for UA, change the heating design day, or raise the
#    **   ~~~   **   system heating design supply air temperature. Also check to make sure the Preheat
#    **   ~~~   **   Design Temperature is not the same as the Central Heating Design Supply Air Temperature.
#    ** Warning ** Chiller:Absorption, Name=ABSORPTION CHILLER
#    **   ~~~   ** ...Generator fluid type must be Steam if generator inlet/outlet nodes are blank.
#    **   ~~~   ** ...Generator fluid type is set to Steam and the simulation continues.
#    ** Warning ** ZoneHVAC:FourPipeFanCoil="FAN COIL- CORRIDORB- VAR FAN CONST FLUID FLOW" -- Exceeded max iterations while adjusting cycling fan sensible runtime to meet the zone load within the cooling convergence tolerance.
#    **   ~~~   ** Iterations=100 During Warmup, Environment=TEHRAN MEHRABAD ANN CLG .4% CONDNS DB=>MWB, at Simulation time=07/21 00:00 - 00:10
#    ** Warning ** Output:Meter: invalid Key Name="DISTRICTCOOLING:FACILITY" - not found.
#    ** Warning ** Output:Meter: invalid Key Name="DISTRICTHEATING:FACILITY" - not found.
#    ** Warning ** Output:Meter:MeterFileOnly requested for "Electricity:Facility" (TimeStep), already on "Output:Meter". Will report to both eplusout.eso and eplusout.mtr
#    ************* Testing Individual Branch Integrity
#    ************* All Branches passed integrity testing
#    ************* Testing Individual Supply Air Path Integrity
#    ************* All Supply Air Paths passed integrity testing
#    ************* Testing Individual Return Air Path Integrity
#    ************* All Return Air Paths passed integrity testing
#    ************* No node connection errors were found.
#    ************* Beginning Simulation
#    ** Warning ** Processing Monthly Tabular Reports: Variable names not valid for this simulation
#    **   ~~~   ** ...use Output:Diagnostics,DisplayExtraWarnings; to show more details on individual variables.
#    ** Warning ** ZoneHVAC:FourPipeFanCoil="FAN COIL- CORRIDOE2- VAR FAN CONST FLUID FLOW" -- Exceeded max iterations while adjusting cycling fan sensible runtime to meet the zone load within the heating convergence tolerance.
#    **   ~~~   ** ...Requested zone load = 265.052 [W]
#    **   ~~~   ** ...Fan coil capacity   = 274.147 [W]
#    **   ~~~   ** Iterations=100 Environment=RUN PERIOD 1, at Simulation time=01/03 11:40 - 11:50
#    ** Warning ** ZoneHVAC:FourPipeFanCoil="FAN COIL- CORRIDOE1- VAR FAN CONST FLUID FLOW" -- Exceeded max iterations while adjusting cycling fan sensible runtime to meet the zone load within the heating convergence tolerance.
#    **   ~~~   ** ...Requested zone load = 250.446 [W]
#    **   ~~~   ** ...Fan coil capacity   = 247.850 [W]
#    **   ~~~   ** Iterations=100 Environment=RUN PERIOD 1, at Simulation time=01/03 16:00 - 16:05
#    ** Warning ** ZoneHVAC:FourPipeFanCoil="FAN COIL- CORRIDOE3- VAR FAN CONST FLUID FLOW" -- Exceeded max iterations while adjusting cycling fan sensible runtime to meet the zone load within the heating convergence tolerance.
#    **   ~~~   ** ...Requested zone load = 313.931 [W]
#    **   ~~~   ** ...Fan coil capacity   = 325.968 [W]
#    **   ~~~   ** Iterations=100 Environment=RUN PERIOD 1, at Simulation time=01/09 12:20 - 12:30
#    ** Warning ** ZoneHVAC:FourPipeFanCoil="FAN COIL- CORRIDOEG- VAR FAN CONST FLUID FLOW" -- Exceeded max iterations while adjusting cycling fan sensible runtime to meet the zone load within the heating convergence tolerance.
#    **   ~~~   ** ...Requested zone load = 223.813 [W]
#    **   ~~~   ** ...Fan coil capacity   = 230.697 [W]
#    **   ~~~   ** Iterations=100 Environment=RUN PERIOD 1, at Simulation time=02/23 08:30 - 08:40
#    ** Warning ** ZoneHVAC:FourPipeFanCoil="FAN COIL- CORRIDORB- VAR FAN CONST FLUID FLOW" -- Exceeded max iterations while adjusting cycling fan sensible runtime to meet the zone load within the heating convergence tolerance.
#    **   ~~~   ** ...Requested zone load = 217.305 [W]
#    **   ~~~   ** ...Fan coil capacity   = 223.117 [W]
#    **   ~~~   ** Iterations=100 Environment=RUN PERIOD 1, at Simulation time=02/24 10:50 - 11:00
#    ** Warning ** GetDensityGlycol: Temperature is out of range (too high) for fluid [WATER] density **
#    **   ~~~   ** ..Called From:PlantPumps:CalcPumps: ,Temperature=[100.01], supplied data range=[0.00,100.00]
#    **   ~~~   **  Environment=RUN PERIOD 1, at Simulation time=04/02 16:30 - 16:40
#    ** Warning ** SimHVAC: Maximum iterations (20) exceeded for all HVAC loops, at RUN PERIOD 1, 04/02 19:40 - 19:50
#    **   ~~~   ** The solution for one or more of the Air Loop HVAC systems did not appear to converge
#    **   ~~~   ** ...use Output:Diagnostics,DisplayExtraWarnings; to show more details on each max iteration exceeded.
#    ** Warning ** SimHVAC: Maximum iterations (20) exceeded for all HVAC loops, at RUN PERIOD 1, 05/01 19:20 - 19:30
#    **   ~~~   ** The solution for one or more of the Air Loop HVAC systems did not appear to converge
#    ** Warning ** SimHVAC: Maximum iterations (20) exceeded for all HVAC loops, at RUN PERIOD 1, 05/02 18:50 - 19:00
#    **   ~~~   ** The solution for one or more of the Air Loop HVAC systems did not appear to converge
#    ** Warning ** SimHVAC: Maximum iterations (20) exceeded for all HVAC loops, at RUN PERIOD 1, 05/07 18:40 - 18:50
#    **   ~~~   ** The solution for one or more of the Air Loop HVAC systems did not appear to converge
#    ** Warning ** SimHVAC: Maximum iterations (20) exceeded for all HVAC loops, at RUN PERIOD 1, 05/07 18:50 - 19:00
#    **   ~~~   ** The solution for one or more of the Air Loop HVAC systems did not appear to converge
#    ** Warning ** SimHVAC: Maximum iterations (20) exceeded for all HVAC loops, at RUN PERIOD 1, 05/13 18:50 - 19:00
#    **   ~~~   ** The solution for one or more of the Air Loop HVAC systems did not appear to converge
#    ** Warning ** SimHVAC: Maximum iterations (20) exceeded for all HVAC loops, at RUN PERIOD 1, 05/13 19:00 - 19:10
#    **   ~~~   ** The solution for one or more of the Air Loop HVAC systems did not appear to converge
#    ** Warning ** SimHVAC: Maximum iterations (20) exceeded for all HVAC loops, at RUN PERIOD 1, 05/13 19:35 - 19:37
#    **   ~~~   ** The solution for one or more of the Air Loop HVAC systems did not appear to converge
#    ** Warning ** SimHVAC: Maximum iterations (20) exceeded for all HVAC loops, at RUN PERIOD 1, 05/16 22:32 - 22:34
#    **   ~~~   ** The solution for one or more of the Air Loop HVAC systems did not appear to converge
#    ** Warning ** SimHVAC: Maximum iterations (20) exceeded for all HVAC loops, at RUN PERIOD 1, 05/16 22:40 - 22:50
#    **   ~~~   ** The solution for one or more of the Air Loop HVAC systems did not appear to converge
#    ** Warning ** SimHVAC: Maximum iterations (20) exceeded for all HVAC loops, at RUN PERIOD 1, 05/16 22:50 - 23:00
#    **   ~~~   ** The solution for one or more of the Air Loop HVAC systems did not appear to converge
#    ** Warning ** SimHVAC: Maximum iterations (20) exceeded for all HVAC loops, at RUN PERIOD 1, 05/16 23:18 - 23:20
#    **   ~~~   ** The solution for one or more of the Air Loop HVAC systems did not appear to converge
#    ** Warning ** SimHVAC: Maximum iterations (20) exceeded for all HVAC loops, at RUN PERIOD 1, 05/19 22:03 - 22:05
#    **   ~~~   ** The solution for one or more of the Air Loop HVAC systems did not appear to converge
#    ** Warning ** SimHVAC: Maximum iterations (20) exceeded for all HVAC loops, at RUN PERIOD 1, 05/19 22:40 - 22:50
#    **   ~~~   ** The solution for one or more of the Air Loop HVAC systems did not appear to converge
#    ** Warning ** The resource referenced by LifeCycleCost:UsePriceEscalation= "U.S. AVG  COMMERCIAL-ELECTRICITY" has no energy cost.
#    **   ~~~   ** ... It is likely that the wrong resource is used. The resource should match the meter used in Utility:Tariff.
#    ** Warning ** The resource referenced by LifeCycleCost:UsePriceEscalation= "U.S. AVG  COMMERCIAL-DISTILLATE OIL" has no energy cost.
#    **   ~~~   ** ... It is likely that the wrong resource is used. The resource should match the meter used in Utility:Tariff.
#    ** Warning ** The resource referenced by LifeCycleCost:UsePriceEscalation= "U.S. AVG  COMMERCIAL-RESIDUAL OIL" has no energy cost.
#    **   ~~~   ** ... It is likely that the wrong resource is used. The resource should match the meter used in Utility:Tariff.
#    ** Warning ** The resource referenced by LifeCycleCost:UsePriceEscalation= "U.S. AVG  COMMERCIAL-NATURAL GAS" has no energy cost.
#    **   ~~~   ** ... It is likely that the wrong resource is used. The resource should match the meter used in Utility:Tariff.
#    ** Warning ** The resource referenced by LifeCycleCost:UsePriceEscalation= "U.S. AVG  COMMERCIAL-COAL" has no energy cost.
#    **   ~~~   ** ... It is likely that the wrong resource is used. The resource should match the meter used in Utility:Tariff.
#    ************* Simulation Error Summary *************
#    ************* There are 33 unused schedules in input.
#    ************* There are 40 unused week schedules in input.
#    ************* There are 91 unused day schedules in input.
#    ************* Use Output:Diagnostics,DisplayUnusedSchedules; to see them.
#    *************
#    ************* ===== Recurring Error Summary =====
#    ************* The following recurring error messages occurred.
#    *************
#    *************  ** Warning ** ZoneHVAC:FourPipeFanCoil="FAN COIL- CORRIDOE1- VAR FAN CONST FLUID FLOW"  -- Exceeded max iterations error (sensible runtime) continues...
#    *************  **   ~~~   **   This error occurred 868 total times;
#    *************  **   ~~~   **   during Warmup 9 times;
#    *************  **   ~~~   **   during Sizing 0 times.
#    *************
#    *************  ** Warning ** ZoneHVAC:FourPipeFanCoil="FAN COIL- CORRIDOE2- VAR FAN CONST FLUID FLOW"  -- Exceeded max iterations error (sensible runtime) continues...
#    *************  **   ~~~   **   This error occurred 22736 total times;
#    *************  **   ~~~   **   during Warmup 9 times;
#    *************  **   ~~~   **   during Sizing 0 times.
#    *************
#    *************  ** Warning ** ZoneHVAC:FourPipeFanCoil="FAN COIL- CORRIDOE3- VAR FAN CONST FLUID FLOW"  -- Exceeded max iterations error (sensible runtime) continues...
#    *************  **   ~~~   **   This error occurred 36308 total times;
#    *************  **   ~~~   **   during Warmup 9 times;
#    *************  **   ~~~   **   during Sizing 0 times.
#    *************
#    *************  ** Warning ** ZoneHVAC:FourPipeFanCoil="FAN COIL- CORRIDOEG- VAR FAN CONST FLUID FLOW"  -- Exceeded max iterations error (sensible runtime) continues...
#    *************  **   ~~~   **   This error occurred 24203 total times;
#    *************  **   ~~~   **   during Warmup 9 times;
#    *************  **   ~~~   **   during Sizing 0 times.
#    *************
#    *************  ** Warning ** ZoneHVAC:FourPipeFanCoil="FAN COIL- CORRIDORB- VAR FAN CONST FLUID FLOW"  -- Exceeded max iterations error (sensible runtime) continues...
#    *************  **   ~~~   **   This error occurred 10069 total times;
#    *************  **   ~~~   **   during Warmup 6 times;
#    *************  **   ~~~   **   during Sizing 0 times.
#    *************
#    *************  ** Warning ** GetDensityGlycol: Temperature out of range (too high) for fluid [WATER] density **
#    *************  **   ~~~   **   This error occurred 7646685 total times;
#    *************  **   ~~~   **   during Warmup 0 times;
#    *************  **   ~~~   **   during Sizing 0 times.
#    *************  **   ~~~   **   Max=113.328741 {C}  Min=100.000189 {C}
#    *************
#    *************  ** Warning ** Plant loop exceeding upper temperature limit, PlantLoop="HOT WATER LOOP-DOEE"
#    *************  **   ~~~   **   This error occurred 203830 total times;
#    *************  **   ~~~   **   during Warmup 0 times;
#    *************  **   ~~~   **   during Sizing 0 times.
#    *************  **   ~~~   **   Max=113.328741
#    *************
#    *************  ** Warning ** SimHVAC: Exceeding Maximum iterations for all HVAC loops, during RUN PERIOD 1 continues
#    *************  **   ~~~   **   This error occurred 574 total times;
#    *************  **   ~~~   **   during Warmup 0 times;
#    *************  **   ~~~   **   during Sizing 0 times.
#    *************
#    *************
#    ************* ===== Final Error Summary =====
#    ************* The following error categories occurred.  Consider correcting or noting.
#    ************* Nominally Unused Constructions
#    ************* ..The nominally unused constructions warning is provided to alert you to potential conditions that can cause
#    ************* ..extra time during simulation. Each construction is calculated by the algorithm indicated in the HeatBalanceAlgorithm
#    ************* ..object. You may remove the constructions indicated (when you use the DisplayExtraWarnings option).
#    *************
#    ************* EnergyPlus Warmup Error Summary. During Warmup: 0 Warning; 0 Severe Errors.
#    ************* EnergyPlus Sizing Error Summary. During Sizing: 20 Warning; 0 Severe Errors.
#    ************* EnergyPlus Completed Successfully-- 7945340 Warning; 0 Severe Errors; Elapsed Time=00hr 03min 18.56sec

# %%
s

# %%
# retrieve hourly output (.eso file)
hourly_output = s.get_out_eso()

# ask for datetime index on year 2013
hourly_output.create_datetime_index(2018)

# get Pandas dataframe
df = hourly_output.get_data()

# monthly resample and display
#print(df[[
#    "environment,Site Outdoor Air Drybulb Temperature",
#    "main zone,Zone Mean Air Temperature"
#]].resample("MS").mean())

# %%
df
# Out:
#                      month  day  hour  minute  end_minute  dst day_type  \
# 2018-01-01 00:00:00      1    1     0       0          10    0   Sunday
# 2018-01-01 00:10:00      1    1     0      10          20    0   Sunday
# 2018-01-01 00:20:00      1    1     0      20          30    0   Sunday
# 2018-01-01 00:30:00      1    1     0      30          40    0   Sunday
# 2018-01-01 00:40:00      1    1     0      40          50    0   Sunday
# ...                    ...  ...   ...     ...         ...  ...      ...
# 2018-12-31 23:10:00     12   31    23      10          20    0   Sunday
# 2018-12-31 23:20:00     12   31    23      20          30    0   Sunday
# 2018-12-31 23:30:00     12   31    23      30          40    0   Sunday
# 2018-12-31 23:40:00     12   31    23      40          50    0   Sunday
# 2018-12-31 23:50:00     12   31    23      50          60    0   Sunday
#
#                      thermal zone: amphitheater,Zone Air Temperature  \
# 2018-01-01 00:00:00                                        21.997613
# 2018-01-01 00:10:00                                        22.004095
# 2018-01-01 00:20:00                                        22.001182
# 2018-01-01 00:30:00                                        21.993350
# 2018-01-01 00:40:00                                        22.005370
# ...                                                              ...
# 2018-12-31 23:10:00                                        21.989553
# 2018-12-31 23:20:00                                        22.004613
# 2018-12-31 23:30:00                                        22.005449
# 2018-12-31 23:40:00                                        22.001279
# 2018-12-31 23:50:00                                        21.995116
#
#                      thermal zone: conferance,Zone Air Temperature  \
# 2018-01-01 00:00:00                                      21.989802
# 2018-01-01 00:10:00                                      22.007885
# 2018-01-01 00:20:00                                      22.007109
# 2018-01-01 00:30:00                                      22.001093
# 2018-01-01 00:40:00                                      21.992476
# ...                                                            ...
# 2018-12-31 23:10:00                                      21.990013
# 2018-12-31 23:20:00                                      22.004386
# 2018-12-31 23:30:00                                      22.004271
# 2018-12-31 23:40:00                                      21.999661
# 2018-12-31 23:50:00                                      21.993301
#
#                      thermal zone: corridor1,Zone Air Temperature  ...  \
# 2018-01-01 00:00:00                                     21.999501  ...
# 2018-01-01 00:10:00                                     22.000781  ...
# 2018-01-01 00:20:00                                     22.000369  ...
# 2018-01-01 00:30:00                                     21.999283  ...
# 2018-01-01 00:40:00                                     21.999775  ...
# ...                                                           ...  ...
# 2018-12-31 23:10:00                                     21.999990  ...
# 2018-12-31 23:20:00                                     21.999888  ...
# 2018-12-31 23:30:00                                     21.999869  ...
# 2018-12-31 23:40:00                                     21.999863  ...
# 2018-12-31 23:50:00                                     21.999858  ...
#
#                      ahu lab,Air System Outdoor Air Flow Fraction  \
# 2018-01-01 00:00:00                                         0.063
# 2018-01-01 00:10:00                                         0.063
# 2018-01-01 00:20:00                                         0.063
# 2018-01-01 00:30:00                                         0.063
# 2018-01-01 00:40:00                                         0.063
# ...                                                           ...
# 2018-12-31 23:10:00                                         0.063
# 2018-12-31 23:20:00                                         0.063
# 2018-12-31 23:30:00                                         0.063
# 2018-12-31 23:40:00                                         0.063
# 2018-12-31 23:50:00                                         0.063
#
#                      ahu library,Air System Outdoor Air Flow Fraction  \
# 2018-01-01 00:00:00                                             0.063
# 2018-01-01 00:10:00                                             0.063
# 2018-01-01 00:20:00                                             0.063
# 2018-01-01 00:30:00                                             0.063
# 2018-01-01 00:40:00                                             0.063
# ...                                                               ...
# 2018-12-31 23:10:00                                             0.063
# 2018-12-31 23:20:00                                             0.063
# 2018-12-31 23:30:00                                             0.063
# 2018-12-31 23:40:00                                             0.063
# 2018-12-31 23:50:00                                             0.063
#
#                      ahu north-gf,Air System Outdoor Air Flow Fraction  \
# 2018-01-01 00:00:00                                              0.063
# 2018-01-01 00:10:00                                              0.063
# 2018-01-01 00:20:00                                              0.063
# 2018-01-01 00:30:00                                              0.063
# 2018-01-01 00:40:00                                              0.063
# ...                                                                ...
# 2018-12-31 23:10:00                                              0.063
# 2018-12-31 23:20:00                                              0.063
# 2018-12-31 23:30:00                                              0.063
# 2018-12-31 23:40:00                                              0.063
# 2018-12-31 23:50:00                                              0.063
#
#                      ahu north1-2,Air System Outdoor Air Flow Fraction  \
# 2018-01-01 00:00:00                                              0.063
# 2018-01-01 00:10:00                                              0.063
# 2018-01-01 00:20:00                                              0.063
# 2018-01-01 00:30:00                                              0.063
# 2018-01-01 00:40:00                                              0.063
# ...                                                                ...
# 2018-12-31 23:10:00                                              0.063
# 2018-12-31 23:20:00                                              0.063
# 2018-12-31 23:30:00                                              0.063
# 2018-12-31 23:40:00                                              0.063
# 2018-12-31 23:50:00                                              0.063
#
#                      ahu north3,Air System Outdoor Air Flow Fraction  \
# 2018-01-01 00:00:00                                            0.063
# 2018-01-01 00:10:00                                            0.063
# 2018-01-01 00:20:00                                            0.063
# 2018-01-01 00:30:00                                            0.063
# 2018-01-01 00:40:00                                            0.063
# ...                                                              ...
# 2018-12-31 23:10:00                                            0.063
# 2018-12-31 23:20:00                                            0.063
# 2018-12-31 23:30:00                                            0.063
# 2018-12-31 23:40:00                                            0.063
# 2018-12-31 23:50:00                                            0.063
#
#                      ahu south-gf,Air System Outdoor Air Flow Fraction  \
# 2018-01-01 00:00:00                                              0.063
# 2018-01-01 00:10:00                                              0.063
# 2018-01-01 00:20:00                                              0.063
# 2018-01-01 00:30:00                                              0.063
# 2018-01-01 00:40:00                                              0.063
# ...                                                                ...
# 2018-12-31 23:10:00                                              0.063
# 2018-12-31 23:20:00                                              0.063
# 2018-12-31 23:30:00                                              0.063
# 2018-12-31 23:40:00                                              0.063
# 2018-12-31 23:50:00                                              0.063
#
#                      ahu south1-2,Air System Outdoor Air Flow Fraction  \
# 2018-01-01 00:00:00                                              0.063
# 2018-01-01 00:10:00                                              0.063
# 2018-01-01 00:20:00                                              0.063
# 2018-01-01 00:30:00                                              0.063
# 2018-01-01 00:40:00                                              0.063
# ...                                                                ...
# 2018-12-31 23:10:00                                              0.063
# 2018-12-31 23:20:00                                              0.063
# 2018-12-31 23:30:00                                              0.063
# 2018-12-31 23:40:00                                              0.063
# 2018-12-31 23:50:00                                              0.063
#
#                      ahu south3,Air System Outdoor Air Flow Fraction  \
# 2018-01-01 00:00:00                                            0.063
# 2018-01-01 00:10:00                                            0.063
# 2018-01-01 00:20:00                                            0.063
# 2018-01-01 00:30:00                                            0.063
# 2018-01-01 00:40:00                                            0.063
# ...                                                              ...
# 2018-12-31 23:10:00                                            0.063
# 2018-12-31 23:20:00                                            0.063
# 2018-12-31 23:30:00                                            0.063
# 2018-12-31 23:40:00                                            0.063
# 2018-12-31 23:50:00                                            0.063
#
#                      electricity:facility,Meter  gas:facility,Meter
# 2018-01-01 00:00:00                1.391709e+07        2.093566e+08
# 2018-01-01 00:10:00                1.416275e+07        2.156087e+08
# 2018-01-01 00:20:00                1.442678e+07        2.216187e+08
# 2018-01-01 00:30:00                1.470563e+07        2.276532e+08
# 2018-01-01 00:40:00                1.500010e+07        2.340035e+08
# ...                                         ...                 ...
# 2018-12-31 23:10:00                1.500322e+07        2.337847e+08
# 2018-12-31 23:20:00                1.503477e+07        2.342937e+08
# 2018-12-31 23:30:00                1.506090e+07        2.348249e+08
# 2018-12-31 23:40:00                1.508673e+07        2.354309e+08
# 2018-12-31 23:50:00                1.511284e+07        2.360430e+08
#
# [52560 rows x 53 columns]

# %%
import pandas as pd
df=pd.DataFrame(data=df)

# %%
import pandas as pd
df2=df[['month','electricity:facility,Meter','gas:facility,Meter']]
df2
# Out:
#                      month  electricity:facility,Meter  gas:facility,Meter
# 2018-01-01 00:00:00      1                1.391709e+07        2.093566e+08
# 2018-01-01 00:10:00      1                1.416275e+07        2.156087e+08
# 2018-01-01 00:20:00      1                1.442678e+07        2.216187e+08
# 2018-01-01 00:30:00      1                1.470563e+07        2.276532e+08
# 2018-01-01 00:40:00      1                1.500010e+07        2.340035e+08
# ...                    ...                         ...                 ...
# 2018-12-31 23:10:00     12                1.500322e+07        2.337847e+08
# 2018-12-31 23:20:00     12                1.503477e+07        2.342937e+08
# 2018-12-31 23:30:00     12                1.506090e+07        2.348249e+08
# 2018-12-31 23:40:00     12                1.508673e+07        2.354309e+08
# 2018-12-31 23:50:00     12                1.511284e+07        2.360430e+08
#
# [52560 rows x 3 columns]

# %%
df3=df2.groupby('month').sum()
df3
# Out:
#        electricity:facility,Meter  gas:facility,Meter
# month
# 1                    1.444142e+11        6.919008e+11
# 2                    1.291086e+11        5.458014e+11
# 3                    1.353026e+11        2.476451e+11
# 4                    1.157618e+11        0.000000e+00
# 5                    1.784615e+11        0.000000e+00
# 6                    2.068865e+11        0.000000e+00
# 7                    2.125776e+11        0.000000e+00
# 8                    2.241192e+11        0.000000e+00
# 9                    1.925998e+11        0.000000e+00
# 10                   1.521888e+11        0.000000e+00
# 11                   1.327756e+11        2.998814e+11
# 12                   1.386063e+11        6.091834e+11

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


# %matplotlib inline
#When using the 'inline' backend, your matplotlib graphs will be included in your notebook, next to the code.

import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df3.plot.bar(x=None,y='gas:facility,Meter')
# Out:
# <AxesSubplot:xlabel='month'>
